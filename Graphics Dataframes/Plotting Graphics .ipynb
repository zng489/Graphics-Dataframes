# %%
#PLOTTING GRAPHICS

# %%
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.patches as mpatche

# %%
#Creating Pandas DataFrame with random numbers

df = pd.DataFrame(np.random.randint(0,100,size=(15, 4)), columns=list('ABCD'))

print(df)
# Out:
#      A   B   C   D
# 0   65  95  70  84
# 1   56   3  42  24
# 2   30  73  93  71
# 3   66  33  47   3
# 4   38  74  26  79
# 5    3  42  57   0
# 6   71  94  68   9
# 7   10  85  96  70
# 8   43  33  51  38
# 9   87   4  14  28
# 10  54  37  19  97
# 11  70  44  79  99
# 12  56  86  60   7
# 13  93  62  46  53
# 14  42  50  45  51

# %%
import numpy as np
import matplotlib.pyplot as plt

df.plot(x='A',y='B',marker='>',markersize=12,markerfacecolor='blue',
        label='line one testing', linewidth=3, color='red')

plt.xlabel('Ax X name')
plt.ylabel('Ax Y name')
plt.legend(title='NAME $BMI.Sn_{2}Cl_{5}$')


df.plot(x='C',y='D', label='line two testing')

plt.xlabel('Log(Mw)')
plt.ylabel('d(wt)/d[log(Mw)]')
plt.legend(title='$BMI.Sn_{2}Cl_{5}$')

plt.show()

################################################################################################################################

import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

#Basicamente voce bota os 2 plots de df em um unico grafico ax.
#BASICALLY YOU ARE PUTTING IN TWO GRAPHS PLOTS IN 'ax=ax' AND TURNING INTO JUST ONLY ONE.

df.plot(x='A',y='B', ax=ax, label='line one testing',)
df.plot(x='C',y='D', ax=ax, label='line two testing')

plt.xlabel('Ax X name')
plt.ylabel('Ax Y name')
plt.legend(title='NAME $BMI.Sn_{2}Cl_{5}$')

#SAVING THE GRAPH.
#plt.savefig("GPCbmisn2cl5.jpg", format='jpg', dpi=1200)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt



df.plot(x='A',y='B',marker='>',markersize=12,markerfacecolor='blue',
        label='line one testing', linewidth=3, color='red')

plt.xlabel('Ax X name')
plt.ylabel('Ax Y name')
plt.legend(title='NAME $BMI.Sn_{2}Cl_{5}$')


C = df['C']
plt.plot(C,df['D'], label='line two testing')

plt.xlabel('Log(Mw)')
plt.ylabel('d(wt)/d[log(Mw)]')
plt.legend(title='$BMI.Sn_{2}Cl_{5}$', bbox_to_anchor=(1.05, 1), loc=2)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# create multiple plots via plt.subplots(rows,columns)
fig, axes = plt.subplots(2,2)

# just plot things on each individual axes
x = np.linspace(0.0,100,20)
y1 = np.random.normal(scale=0.2,size=20)
y2 = np.random.normal(scale=0.5,size=20)
y3 = np.random.normal(scale=0.8,size=20)

# one plot on each subplot
axes[0][0].scatter(x,y1)
axes[0][1].bar(x,y1)
axes[1][0].scatter(x,y2)
axes[1][1].plot(x,y2)

# you can set a legend for a single subplot
axes[1][1].legend(['plot 4'])

plt.show()

# %%
sns.set(style='ticks')

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(222)


sns.lineplot(df['C'],df['D']-0.5, label='130°C-1:800-In')

plt.show()

# %%
#plt.axis([1,1000,1,1000])


plt.ylim(0.5,-4.5)
plt.xlim(3300,500)


plt.xticks(np.arange(500,3500,step=250))
plt.yticks(np.arange(100,0.5,step=100)) #0.5))

plt.title('PLA produzido com a utilização de $BMI.In_{2}Cl_{7}$',fontsize=18)
plt.xlabel('Número de onda cm$^{-1}$',fontsize=14)
plt.ylabel('',fontsize=14)

#plt.savefig("fssssss.svg", format='svg', dpi=1200)
#plt.savefig("BMICU2CL3.eps", format='eps')

plt.annotate('', xy=(2000, 0), xycoords='data', ha='center',
            xytext=(0,0), textcoords='offset points')

plt.savefig("bmiin2cl7.jpg", format='jpg', dpi=1200)

#plt.legend(title='$BMI.In_{2}Cl_{7}$', bbox_to_anchor=(1.15, 1), shadow=False, ncol=1)

plt.legend(title='$BMI.In_{2}Cl_{7}$', loc='lower left', frameon=False)
#In.to_excel("in_pandas.xlsx")
plt.show()

#(ax2,ax3,ax4) = plt.subplots(figsize=(7,7))

#ax2 = plt.subplot2grid((2, 3), (1, 0), colspan=1)
#ax2.plot( x,y, marker='o', color="grey", alpha=0.3)

#ax3 = plt.subplot2grid((2, 3), (1, 1), colspan=1)
#ax3.plot( x,y, marker='o', color="grey", alpha=0.3)


#ax4 = plt.subplot2grid((2, 3), (1, 2), colspan=1)
#ax4.plot( x,y, marker='o', color="grey", alpha=0.3)

# %%
df = sns.load_dataset("penguins")
sns.pairplot(df)

# %%
df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species")

# %%
df = sns.load_dataset("penguins")
sns.pairplot(df, hue="species", diag_kind="hist")

# %%
df = sns.load_dataset("penguins")
sns.pairplot(df, kind="kde")

# %%
https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
fig = plt.figure(figsize=(10,6))
#fig = plt.figure(figsize=(16,12))

ax = fig.subplots(221)
ax.plt(df['B'], df['D'], label='22')



#sns.lineplot(df['A'], df['B'], label='22')
#sns.lineplot(df['C'], df['D'], label='23')



#plt.ylim(30,250)
#plt.xlim(3300,500)



#plt.xticks(np.arange(500,3500,step=250))
#plt.yticks(np.arange(100,0.5,step=100)) #0.5))



plt.xlabel('Numero de ondas')
plt.ylabel('')
plt.legend(title='$BMI.Sn_{2}Cl_{5}$', bbox_to_anchor=(1.05, 1), loc=2)



plt.show()

# %%
infra1 = pd.read_csv('er.txt', delimiter='\t', names=['n_ondas','transm'])

cu_ondasB = pd.to_numeric(cu_df['Bn110°C-1:800-Cu'], errors='coerce')

cu_ondasB.dtypes

# %%
sns.set(style='ticks')

fig = plt.figure(figsize=(10,6))

ax1 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
ax1.plot( x,y, marker='o', alpha=0.4)

#ax2 = plt.subplot2grid((2, 2), (1, 0), colspan=1)
#ax2.plot( 'x','z', data=df, marker='o', color="grey", alpha=0.3)

#ax3 = plt.subplot2grid((2, 2), (1, 1), colspan=1)
#ax3.plot( 'x','z', data=df, marker='o', color="orange", alpha=0.3

ax1 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
ax1.plot( x,y, marker='o', alpha=0.4)

ax1 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
ax1.plot( x,y, marker='o', alpha=0.4)

# %%
sns.set(style='ticks')

fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)

#sns.lineplot(x, y1,label='sdsd')

sns.lineplot(Sn['sn-ondas-130-800'],Sn['sn-trans-130-800']-2, label='130°C-1:800-Sn')
sns.lineplot(Sn['sn-ondas-130-500'],Sn['sn-trans-130-500']-6.5, label='130°C-1:500-Sn')

sns.lineplot(Sn['sn1-ondas-120-650'],Sn['sn1-trans-120-650'], label='120°C-1:650-Sn1')


sns.lineplot(Sn['sn-ondas-110-800'],Sn['sn-trans-110-800'], label='110°C-1:800-Sn')

sns.lineplot(Sn['sn-ondas-110-500'],Sn['sn-trans-110-500']+7, label='110°C-1:500-Sn')

#plt.axis([1,1000,1,1000])


#plt.ylim(0.5,-4.5)

plt.ylim(1,-15)
plt.xlim(3800,500)


plt.xticks(np.arange(500,3800,step=250))
plt.yticks(np.arange(100,0.5,step=100)) #0.5))

plt.title('PLA produzido com a utilização de $BMI.Sn_{2}Cl_{5}$',fontsize=18)
plt.xlabel('Número de onda cm$^{-1}$',fontsize=14)
plt.ylabel('',fontsize=14)

#plt.savefig("fssssss.svg", format='svg', dpi=1200)
#plt.savefig("BMICU2CL3.eps", format='eps')

plt.annotate('', xy=(2000, 0), xycoords='data', ha='center',
            xytext=(0,0), textcoords='offset points')

plt.savefig("bmisn-02cl5.jpg", format='jpg', dpi=1200)


ax.set_position([0.1,0.1,0.5,0.8])

plt.legend(title='$BMI.Sn_{2}Cl_{5}$', frameon=True, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
#plt.legend(title='$BMI.In_{2}Cl_{7}$', loc='lower left', frameon=False)
 #bbox_to_anchor=(1.15, 1), shadow=False, ncol=1


Sn.to_excel("Sn1.xlsx")
plt.show()

#(ax2,ax3,ax4) = plt.subplots(figsize=(7,7))

#ax2 = plt.subplot2grid((2, 3), (1, 0), colspan=1)
#ax2.plot( x,y, marker='o', color="grey", alpha=0.3)

#ax3 = plt.subplot2grid((2, 3), (1, 1), colspan=1)
#ax3.plot( x,y, marker='o', color="grey", alpha=0.3)


#ax4 = plt.subplot2grid((2, 3), (1, 2), colspan=1)
#ax4.plot( x,y, marker='o', color="grey", alpha=0.3)

#plt.show()
